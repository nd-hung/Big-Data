# %%
import pandas as pd
import matplotlib.pyplot as plt 

result = pd.read_csv('part-00000', 'r', delimiter='\t', header=None, names=['year','max_temp','min_temp', 'avg_temp'])

# %%
# Vẽ biểu đồ 
plt.plot(result['year'], result['max_temp'] /10, marker="o",  color='#FF5733', label='Cao nhất')
plt.plot(result['year'], result['min_temp'] /10, marker="o",  color='#17BC08', label='Thấp nhất')
plt.plot(result['year'], result['avg_temp'] /10, marker="o",  color='#2288B3', label='Trung bình')

plt.ylim(-60,70)

plt.legend(loc='upper left')

plt.xlabel('Năm')
plt.ylabel('Nhiệt độ ($^\circ$C)')

plt.show()
